# %%
# !pip install opencv-python
import cv2
import numpy as np
# Out:
# Requirement already satisfied: opencv-python in /home/brian/myenv/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /home/brian/myenv/lib/python3.12/site-packages (from opencv-python) (1.26.4)

# %%
image = cv2.imread(r'C:\Users\User\fruits.JPG')

hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_green = np.array([35, 43, 46])
upper_green = np.array([77, 255, 255])

mask = cv2.inRange(hsv, lower_green, upper_green)

res = cv2.bitwise_and(image, image, mask=mask)

cv2.imshow('Input', image)
cv2.imshow('Result HSV', hsv)
cv2.imshow('Result RES', res)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [ WARN:0@0.022] global loadsave.cpp:241 findDecoder imread_('C:\Users\User\fruits.JPG'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 3
#       1 image = cv2.imread(r'C:\Users\User\fruits.JPG')
# ----> 3 hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
#       5 lower_green = np.array([35, 43, 46])
#       6 upper_green = np.array([77, 255, 255])
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
pip install pygame
# Out:
# Collecting pygame
#   Downloading pygame-2.6.1-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.1-cp312-cp312-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB 325.1 kB/s eta 0:00:33
#    ---------------------------------------- 0.1/10.6 MB 544.7 kB/s eta 0:00:20
#     --------------------------------------- 0.2/10.6 MB 984.6 kB/s eta 0:00:11
#    - -------------------------------------- 0.3/10.6 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/10.6 MB 1.7 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/10.6 MB 1.9 MB/s eta 0:00:06
#    -- ------------------------------------- 0.7/10.6 MB 2.1 MB/s eta 0:00:05
#    --- ------------------------------------ 0.9/10.6 MB 2.3 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/10.6 MB 2.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.2/10.6 MB 2.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/10.6 MB 2.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.5/10.6 MB 2.6 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/10.6 MB 2.7 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/10.6 MB 2.7 MB/s eta 0:00:04
#    ------- -------------------------------- 1.9/10.6 MB 2.8 MB/s eta 0:00:04
#    ------- -------------------------------- 1.9/10.6 MB 2.8 MB/s eta 0:00:04
#    ------- -------------------------------- 1.9/10.6 MB 2.8 MB/s eta 0:00:04
#    ------- -------------------------------- 1.9/10.6 MB 2.8 MB/s eta 0:00:04
#    -------- ------------------------------- 2.3/10.6 MB 2.6 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/10.6 MB 2.6 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/10.6 MB 2.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.7/10.6 MB 2.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.9/10.6 MB 2.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.0/10.6 MB 2.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.2/10.6 MB 2.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.3/10.6 MB 2.7 MB/s eta 0:00:03
#    ------------- -------------------------- 3.5/10.6 MB 2.8 MB/s eta 0:00:03
#    ------------- -------------------------- 3.6/10.6 MB 2.8 MB/s eta 0:00:03
#    -------------- ------------------------- 3.7/10.6 MB 2.8 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/10.6 MB 2.8 MB/s eta 0:00:03
#    --------------- ------------------------ 4.0/10.6 MB 2.8 MB/s eta 0:00:03
#    --------------- ------------------------ 4.2/10.6 MB 2.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.3/10.6 MB 2.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.4/10.6 MB 2.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.4/10.6 MB 2.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.6/10.6 MB 2.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.6/10.6 MB 2.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.7/10.6 MB 2.6 MB/s eta 0:00:03
#    ------------------ --------------------- 4.8/10.6 MB 2.7 MB/s eta 0:00:03
#    ------------------ --------------------- 5.0/10.6 MB 2.7 MB/s eta 0:00:03
#    ------------------- -------------------- 5.1/10.6 MB 2.7 MB/s eta 0:00:03
#    ------------------- -------------------- 5.3/10.6 MB 2.7 MB/s eta 0:00:02
#    -------------------- ------------------- 5.4/10.6 MB 2.7 MB/s eta 0:00:02
#    --------------------- ------------------ 5.6/10.6 MB 2.7 MB/s eta 0:00:02
#    --------------------- ------------------ 5.7/10.6 MB 2.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.9/10.6 MB 2.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.0/10.6 MB 2.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.2/10.6 MB 2.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.4/10.6 MB 2.8 MB/s eta 0:00:02
#    ------------------------ --------------- 6.5/10.6 MB 2.8 MB/s eta 0:00:02
#    ------------------------- -------------- 6.7/10.6 MB 2.8 MB/s eta 0:00:02
#    ------------------------- -------------- 6.8/10.6 MB 2.8 MB/s eta 0:00:02
#    -------------------------- ------------- 7.1/10.6 MB 2.9 MB/s eta 0:00:02
#    --------------------------- ------------ 7.3/10.6 MB 2.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.6/10.6 MB 3.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.9/10.6 MB 3.0 MB/s eta 0:00:01
#    ------------------------------- -------- 8.3/10.6 MB 3.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.5/10.6 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 8.9/10.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.6 MB 3.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------ --- 9.8/10.6 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.1/10.6 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  10.4/10.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 3.6 MB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pygame, sys, time, random

# 設置遊戲難度和畫面大小
difficulty = 25
frame_size_x = 720  
frame_size_y = 480

# 初始化 Pygame
pygame.init()
pygame.display.set_caption('Snake Eater')  
game_window = pygame.display.set_mode((frame_size_x, frame_size_y))

# 定義顏色
black = pygame.Color(0, 0, 0)
white = pygame.Color(255, 255, 255)
red = pygame.Color(255, 0, 0)
green = pygame.Color(0, 255, 0)
blue = pygame.Color(0, 0, 255)

# 控制畫面刷新率
fps_controller = pygame.time.Clock()

# 初始化蛇和食物的位置
snake_pos = [100, 50]
snake_body = [[100, 50], [90, 50], [80, 50]]  
food_pos = [random.randrange(1, (frame_size_x // 10)) * 10, random.randrange(1, (frame_size_y // 10)) * 10]
food_spawn = True

# 初始化方向和分數
direction = 'RIGHT'
change_to = direction
score = 0

# 定義遊戲結束畫面
def game_over():
    my_font = pygame.font.SysFont('times new roman', 90) 
    game_over_surface = my_font.render('YOU DIED', True, red)
    game_over_rect = game_over_surface.get_rect()
    game_over_rect.midtop = (frame_size_x / 2, frame_size_y / 4)
    game_window.fill(black)
    game_window.blit(game_over_surface, game_over_rect)
    show_score(0, red, 'times', 20)
    pygame.display.flip()
    time.sleep(3)
    pygame.quit()
    sys.exit()

# 定義分數顯示功能
def show_score(choice, color, font, size):
    score_font = pygame.font.SysFont(font, size)
    score_surface = score_font.render('Score : ' + str(score), True, color)
    score_rect = score_surface.get_rect()
    if choice == 1:
        score_rect.midtop = (frame_size_x / 10, 15)
    else:
        score_rect.midtop = (frame_size_x / 2, frame_size_y / 1.25)
    game_window.blit(score_surface, score_rect)

# 主遊戲循環
while True:
    # 處理鍵盤輸入事件
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_UP or event.key == ord('w'):
                change_to = 'UP'
            if event.key == pygame.K_DOWN or event.key == ord('s'):
                change_to = 'DOWN'
            if event.key == pygame.K_LEFT or event.key == ord('a'):
                change_to = 'LEFT'
            if event.key == pygame.K_RIGHT or event.key == ord('d'):
                change_to = 'RIGHT'
            if event.key == pygame.K_ESCAPE:
                pygame.event.post(pygame.event.Event(pygame.QUIT))

    # 確保蛇不會向相反方向移動
    if change_to == 'UP' and direction != 'DOWN':
        direction = 'UP'
    if change_to == 'DOWN' and direction != 'UP':
        direction = 'DOWN'
    if change_to == 'LEFT' and direction != 'RIGHT':
        direction = 'LEFT'
    if change_to == 'RIGHT' and direction != 'LEFT':
        direction = 'RIGHT'

    # 根據方向移動蛇
    if direction == 'UP':
        snake_pos[1] -= 10
    if direction == 'DOWN':
        snake_pos[1] += 10
    if direction == 'LEFT':
        snake_pos[0] -= 10
    if direction == 'RIGHT':
        snake_pos[0] += 10

    # 蛇身體增加長度
    snake_body.insert(0, list(snake_pos))
    if snake_pos[0] == food_pos[0] and snake_pos[1] == food_pos[1]:
        score += 1
        food_spawn = False
    else:
        snake_body.pop()

    # 生成新的食物
    if not food_spawn:
        food_pos = [random.randrange(1, (frame_size_x // 10)) * 10, random.randrange(1, (frame_size_y // 10)) * 10]
    food_spawn = True

    # 更新畫面
    game_window.fill(black)
    for pos in snake_body:
        pygame.draw.rect(game_window, green, pygame.Rect(pos[0], pos[1], 10, 10))
    pygame.draw.rect(game_window, white, pygame.Rect(food_pos[0], food_pos[1], 10, 10))

    # 判斷遊戲是否結束
    if snake_pos[0] < 0 or snake_pos[0] > frame_size_x - 10:
        game_over()
    if snake_pos[1] < 0 or snake_pos[1] > frame_size_y - 10:
        game_over()
    for block in snake_body[1:]:
        if snake_pos[0] == block[0] and snake_pos[1] == block[1]:
            game_over()

    # 顯示分數
    show_score(1, white, 'consolas', 20)

    # 更新畫面並控制刷新率
    pygame.display.update()
    fps_controller.tick(difficulty)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pygame, sys, time, random
#       3 # 設置遊戲難度和畫面大小
#       4 difficulty = 25
#
# ModuleNotFoundError: No module named 'pygame'

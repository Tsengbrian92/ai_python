# %%
# !pip install SpeechRecognition gTTS pygame
import speech_recognition
import tempfile
from gtts import gTTS
from pygame import mixer

mixer.init()

def listenTo():
    r = speech_recognition.Recognizer()
    with speech_recognition.Microphone() as source:
        r.adjust_for_ambient_noise(source)
        audio = r.listen(source)
    return r.recognize_google(audio, language='zh-TW')

def speak(sentence):
    with tempfile.NamedTemporaryFile(delete=True) as fp:
        tts = gTTS(text=sentence, lang='zh-TW')
        tts.save("{}.mp3".format(fp.name))
        mixer.music.load("{}.mp3".format(fp.name))
        mixer.music.play()

qa_dict = {
    '你最喜歡的顏色是什麼？': '我最喜歡藍色！',
    '你最喜歡的食物是什麼？': '我喜歡披薩。',
    '你最喜歡的運動是什麼？': '我喜歡游泳！'
}

def chatbot():
    question = listenTo()
    response = qa_dict.get(question, '抱歉，我不懂你的問題。')
    speak(response)

speak('你最喜歡的顏色是什麼？')
speak(qa_dict['你最喜歡的顏色是什麼？'])

speak('你最喜歡的食物是什麼？')
speak(qa_dict['你最喜歡的食物是什麼？'])

speak('你最喜歡的運動是什麼？')
speak(qa_dict['你最喜歡的運動是什麼？'])
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 207.9 kB/s eta 0:00:00m eta 0:00:010:00:05
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 194.4 kB/s eta 0:00:00m eta 0:00:010:03:05
# ...
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# !pip install --upgrade httpcore httpx
# !pip install googletrans==4.0.0-rc1

import speech_recognition
import tempfile

from gtts import gTTS
from pygame import mixer
from googletrans import Translator

mixer.init()

def listenTo():
    r = speech_recognition.Recognizer()
    with speech_recognition.Microphone() as source:
        r.adjust_for_ambient_noise(source)
        audio = r.listen(source)
    return r.recognize_google(audio, language='zh-TW')

def speak(sentence, lang):
    mixer.init()
    with tempfile.NamedTemporaryFile(delete=True) as fp:
        tts = gTTS(text=sentence, lang=lang)
        tts.save("{}.mp3".format(fp.name))
        mixer.music.load("{}.mp3".format(fp.name))
        mixer.music.play()

translator = Translator()

lang = 'ja'
A = translator.translate("今天天氣很好", dest=lang).text
speak(A, lang)
print(A)

B = translator.translate(A, dest='ko').text
print(B)

unknown_sentence = 'おはよう'
results = translator.detect(unknown_sentence)
print(results)
print(results.lang)
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 98.3 kB/s eta 0:00:00 kB/s eta 0:00:04
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=07505e904c959ad4ca6665f303c9831487d68b42267c109620f6efd2b8cf82cc
#   Stored in directory: /home/brian/.cache/pip/wheels/95/0f/04/b17a72024b56a60e499ce1a6313d283ed5ba332407155bee03
# Successfully built googletrans
# ...
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.7
#     Uninstalling httpcore-1.0.7:
# ...

# %%
# !pip install dlib
# !pip install face_recognition
# !pip install face_recognition --no-deps
import face_recognition
import matplotlib.pyplot as plt

image = face_recognition.load_image_file("leader.jpg")

face_locations = face_recognition.face_locations(image)

plt.imshow(image)
plt.axis("off")
plt.show()

print(f"There are {len(face_locations)} people in this image")
# Out:
# Requirement already satisfied: dlib in /home/brian/myenv/lib/python3.12/site-packages (19.24.6)
# Requirement already satisfied: face_recognition in /home/brian/myenv/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: face-recognition-models>=0.3.0 in /home/brian/myenv/lib/python3.12/site-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: Click>=6.0 in /home/brian/myenv/lib/python3.12/site-packages (from face_recognition) (8.1.7)
# Requirement already satisfied: dlib>=19.7 in /home/brian/myenv/lib/python3.12/site-packages (from face_recognition) (19.24.6)
# Requirement already satisfied: numpy in /home/brian/myenv/lib/python3.12/site-packages (from face_recognition) (1.26.4)
# Requirement already satisfied: Pillow in /home/brian/myenv/lib/python3.12/site-packages (from face_recognition) (8.0.0)
# Requirement already satisfied: face_recognition in /home/brian/myenv/lib/python3.12/site-packages (1.3.0)
# There are 3 people in this image

# %%
import face_recognition
import matplotlib.pyplot as plt

image_of_person = face_recognition.load_image_file('./known_faces/Trump1.jpg')
person_face_encoding = face_recognition.face_encodings(image_of_person)[0]
plt.imshow(image_of_person)
plt.title("Known Face (Fa)")
plt.show()

unknown_image = face_recognition.load_image_file('./unknown_faces/Kim.JPG')
unknown_face_encoding = face_recognition.face_encodings(unknown_image)[0]
plt.imshow(unknown_image)
plt.title("Unknown Face")
plt.show()

results = face_recognition.compare_faces([person_face_encoding], unknown_face_encoding)

if results[0]:
    print("This is Fa")
else:
    print("This is NOT Fa")
# Out:
# This is NOT Fa

# %%
from PIL import Image
import face_recognition
import matplotlib.pyplot as plt

image = face_recognition.load_image_file('./identification/people3.jpg')
face_locations = face_recognition.face_locations(image)

num = 1

for face_location in face_locations:
    top, right, bottom, left = face_location
    face_image = image[top:bottom, left:right]
    pil_image = Image.fromarray(face_image)
    pil_image.show()
    filename = f"face{num}.jpg"
    pil_image.save(f'./identification/{filename}')
    num += 1

# %%
# !pip install pillow==8.0.0
import face_recognition
from PIL import Image, ImageDraw


image_of_Fa = face_recognition.load_image_file('./identification/face1.jpg')
Fa_face_encoding = face_recognition.face_encodings(image_of_Fa)[0]
plt.imshow(image_of_Fa)

image_of_Esther = face_recognition.load_image_file('./identification/face2.jpg')
Esther_face_encoding = face_recognition.face_encodings(image_of_Esther)[0]
plt.imshow(image_of_Esther)

image_of_Winston = face_recognition.load_image_file('./identification/face3.jpg')
Winston_face_encoding = face_recognition.face_encodings(image_of_Winston)[0]
plt.imshow(image_of_Winston)

known_face_encodings = [Fa_face_encoding, Winston_face_encoding]
known_face_names = ["Fa", "Winston"]

test_image = face_recognition.load_image_file('./identification/people3.jpg')
plt.imshow(test_image)

face_locations = face_recognition.face_locations(test_image)
face_encodings = face_recognition.face_encodings(test_image, face_locations)
pil_image = Image.fromarray(test_image)
draw = ImageDraw.Draw(pil_image)

for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
    matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
    name = "Unknown Person"
    if True in matches:
        first_match_index = matches.index(True)
        name = known_face_names[first_match_index]
    if True in matches:
        second_match_index = matches.index(True)
        name = known_face_names[second_match_index]
        
    draw.rectangle([(left, top), (right, bottom)], outline=(0, 0, 0))
    #text_width, text_height = draw.textsize(name)
    draw.rectangle([(left, bottom - text_height - 8), (right, bottom)], fill=(0, 0, 255), outline=(0, 0, 0))
    draw.text((left + 6, bottom - text_height - 8), name, fill=(0, 255, 0))
del draw
pil_image.show()
pil_image.save('identify.jpg')
# Out:
# Requirement already satisfied: pillow==8.0.0 in /home/brian/myenv/lib/python3.12/site-packages (8.0.0)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 40
#      37     name = known_face_names[second_match_index]
#      39 draw.rectangle([(left, top), (right, bottom)], outline=(0, 0, 0))
# ---> 40 text_width, text_height = draw.textsize(name)
#      41 draw.rectangle([(left, bottom - text_height - 8), (right, bottom)], fill=(0, 0, 255), outline=(0, 0, 0))
#      42 draw.text((left + 6, bottom - text_height - 8), name, fill=(0, 255, 0))
#
# AttributeError: 'ImageDraw' object has no attribute 'textsize'
